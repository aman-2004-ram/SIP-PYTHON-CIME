# %%
# !pip install seaborn

# %%
import pandas as pd
data = {
"EmpID":[101,102,103,104,105,106,107,108],
"Name":["Amit","Riya","Karan","Priya","John","Meena","Raj","Sara"],
"Department":["IT","HR","IT","Finance","HR","Finance","IT","HR"],
"Salary":[50000,42000,65000,70000,45000,62000,58000,47000],
"Experience":[2,1,5,7,2,6,4,3],
"Gender":["Male","Female","Male","Female","Male","Female","Male","Female"]
}
df = pd.DataFrame(data)

# %%
df=df.to_csv("emp.csv")

# %%
data_emp=pd.read_csv("emp.csv")

# %%
print(data_emp.head())
print(data_emp.tail())
print(data_emp.info())
print(data_emp.describe())
# Out:
#    Unnamed: 0  EmpID   Name Department  Salary  Experience  Gender
# 0           0    101   Amit         IT   50000           2    Male
# 1           1    102   Riya         HR   42000           1  Female
# 2           2    103  Karan         IT   65000           5    Male
# 3           3    104  Priya    Finance   70000           7  Female
# 4           4    105   John         HR   45000           2    Male
#    Unnamed: 0  EmpID   Name Department  Salary  Experience  Gender
# 3           3    104  Priya    Finance   70000           7  Female
# 4           4    105   John         HR   45000           2    Male
# 5           5    106  Meena    Finance   62000           6  Female
# 6           6    107    Raj         IT   58000           4    Male
# 7           7    108   Sara         HR   47000           3  Female
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
# Create Scatter Plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()
sns.scatterplot(
    x="Experience",
    y="Salary",
    data=data_emp
)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    x="Experience",
    y="Salary",
    hue="Department",
    style="Gender",
    data=data_emp
)

plt.title("Experience vs Salary")
plt.show()

# %%
sns.lineplot(
x="Experience",
y="Salary",
hue="Department",
data=data_emp
)
plt.show()

# %%
sns.barplot(
x="Experience",
y="Salary",
hue="Department",
data=data_emp
)
plt.show()

# %%
sns.lineplot(
x="Experience",
y="Salary",
hue="Gender",
data=data_emp
)
plt.show()

# %%
sns.barplot(
x="Experience",
y="Salary",
hue="Gender",
data=data_emp
)
plt.show()

# %%
sns.countplot(
x="Department",
data=data_emp
)
plt.show()

# %%
sns.countplot(
x="Gender",
data=data_emp
)
plt.show()

# %%
sns.kdeplot(data_emp["Salary"])
plt.show()
sns.kdeplot(
data_emp["Salary"],
fill=True
)
plt.show()

# %%
sns.boxplot(
x="Department",
y="Salary",
data=data_emp

)
plt.show()

# %%
sns.violinplot(
x="Department",
y="Salary",
data=data_emp

)
plt.show()

# %%
sns.stripplot(
x="Department",
y="Salary",
data=data_emp

)
plt.show()

# %%
sns.pairplot(data_emp)
plt.show()
sns.pairplot(
data_emp,
hue="Department"
)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load an example dataset
penguins = sns.load_dataset("penguins")

# Create a pair plot
sns.pairplot(penguins)

# Display the plot
plt.show()

# %%
corr = data_emp.corr(numeric_only=True)
sns.heatmap(
corr,
annot=True,
cmap="coolwarm"
)
plt.show()

# %%
sns.jioplot(
x="Department",
y="Salary",
    kind="bar",
data=data_emp

)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sns.jioplot(
#       2 x="Department",
#       3 y="Salary",
#       4     kind="bar",
#
# AttributeError: module 'seaborn' has no attribute 'jioplot'

# %%
sns.catplot(
x="Department",
y="Salary",
    kind="bar",
data=data_emp

)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(
    y="Department",   # Category on Y-axis
    x="Salary",       # Numeric value on X-axis
    kind="bar",
    data=data_emp
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(df, col="Gender")
g.map_dataframe(
    sns.scatterplot,
    x="Experience",
    y="Salary"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 g = sns.FacetGrid(df, col="Gender")
#       5 g.map_dataframe(
#       6     sns.scatterplot,
#       7     x="Experience",
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\axisgrid.py:402, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     400     col_names = []
#     401 else:
# --> 402     col_names = categorical_order(data[col], col_order)
#     404 # Additional dict of kwarg -> list of values for mapping the hue var
#     405 hue_kws = hue_kws if hue_kws is not None else {}
#
# ...

# %%
summary = data_emp.groupby("Department")["Salary"].mean()
sns.barplot(
x=summary.index,
y=summary.values
)
plt.show()

# %%
highest = data_emp.loc[data_emp["Salary"].idxmax()]
sns.barplot(
x=["Highest Salary"],
y=[highest["Salary"]]
)
plt.show()

# %%
sns.scatterplot(
x="Experience",
y="Salary",
hue="Department",
size="Experience",
data=data_emp
)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Employees.csv")
# Summary
print(df.describe())
# Bar Plot
sns.barplot(x="Department", y="Salary", data=df)
plt.title("Average Salary by Department")
plt.show()
# Histogram
sns.histplot(df["Salary"], kde=True)
plt.title("Salary Distribution")
plt.show()
# Scatter Plot
sns.scatterplot(
x="Experience",
y="Salary",
hue="Department",
data=df
)
plt.title("Experience vs Salary")
plt.show()
# Box Plot
sns.boxplot(
x="Department",
y="Salary",
data=df
)
plt.title("Department-wise Salary Distribution")
plt.show()
# Heatmap
sns.heatmap(
df.corr(numeric_only=True),
annot=True,
cmap="coolwarm"
)
plt.title("Correlation Matrix")
plt.show()
# Out:
#            Emp_ID        Salary  Experience
# count    5.000000      5.000000    5.000000
# mean   103.000000  59000.000000    4.200000
# std      1.581139   9617.692031    1.923538
# min    101.000000  45000.000000    2.000000
# 25%    102.000000  55000.000000    3.000000
# 50%    103.000000  60000.000000    4.000000
# 75%    104.000000  65000.000000    5.000000
# max    105.000000  70000.000000    7.000000
